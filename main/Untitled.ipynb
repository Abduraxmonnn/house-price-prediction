# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics

# %%
data = pd.read_csv(r'/home/abduraxmon/Abduraxmon/Django/Univer/house_price_prediction/dataset/USA_Housing.csv')
data.head(10)
# Out:
#    Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0      79545.458574             5.682861                   7.009188
# 1      79248.642455             6.002900                   6.730821
# 2      61287.067179             5.865890                   8.512727
# 3      63345.240046             7.188236                   5.586729
# 4      59982.197226             5.040555                   7.839388
# 5      80175.754159             4.988408                   6.104512
# 6      64698.463428             6.025336                   8.147760
# 7      78394.339278             6.989780                   6.620478
# 8      59927.660813             5.362126                   6.393121
# 9      81885.927184             4.423672                   8.167688
#
#    Avg. Area Number of Bedrooms  Area Population         Price  \
# 0                          4.09     23086.800503  1.059034e+06
# 1                          3.09     40173.072174  1.505891e+06
# ...

# %%
new_data = data.drop(['Address'], axis=1)
new_data.head(10)
# Out:
#    Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0      79545.458574             5.682861                   7.009188
# 1      79248.642455             6.002900                   6.730821
# 2      61287.067179             5.865890                   8.512727
# 3      63345.240046             7.188236                   5.586729
# 4      59982.197226             5.040555                   7.839388
# 5      80175.754159             4.988408                   6.104512
# 6      64698.463428             6.025336                   8.147760
# 7      78394.339278             6.989780                   6.620478
# 8      59927.660813             5.362126                   6.393121
# 9      81885.927184             4.423672                   8.167688
#
#    Avg. Area Number of Bedrooms  Area Population         Price
# 0                          4.09     23086.800503  1.059034e+06
# 1                          3.09     40173.072174  1.505891e+06
# ...

# %%
sns.heatmap(new_data.isnull())
# Out:
# <Axes: >

# %%
new_data.head(10).style.background_gradient(cmap="Greens")
# Out:
# <style type="text/css">
# #T_33d67_row0_col0 {
#   background-color: #006729;
#   color: #f1f1f1;
# }
# #T_33d67_row0_col1, #T_33d67_row0_col5, #T_33d67_row2_col5 {
#   background-color: #84cc83;
#   color: #000000;
# }
# #T_33d67_row0_col2 {
#   background-color: #79c67a;
#   color: #000000;
# }
# #T_33d67_row0_col3 {
#   background-color: #7fc97f;
#   color: #000000;
# }
# #T_33d67_row0_col4, #T_33d67_row3_col2, #T_33d67_row4_col0, #T_33d67_row4_col5, #T_33d67_row8_col0, #T_33d67_row8_col3, #T_33d67_row9_col1 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_33d67_row1_col0, #T_33d67_row9_col2 {
#   background-color: #006b2b;
#   color: #f1f1f1;
# }
# #T_33d67_row1_col1 {
#   background-color: #56b567;
#   color: #f1f1f1;
# }
# #T_33d67_row1_col2 {
#   background-color: #9bd696;
#   color: #000000;
# }
# #T_33d67_row1_col3 {
#   background-color: #d1edcb;
#   color: #000000;
# }
# #T_33d67_row1_col4, #T_33d67_row9_col4 {
#   background-color: #86cc85;
# ...

# %%
new_data.hist(bins=20,figsize=(10,10))
# Out:
# array([[<Axes: title={'center': 'Avg. Area Income'}>,
#         <Axes: title={'center': 'Avg. Area House Age'}>],
#        [<Axes: title={'center': 'Avg. Area Number of Rooms'}>,
#         <Axes: title={'center': 'Avg. Area Number of Bedrooms'}>],
#        [<Axes: title={'center': 'Area Population'}>,
#         <Axes: title={'center': 'Price'}>]], dtype=object)

# %%
X = new_data.drop('Price', axis=1)
Y = new_data['Price']

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=20)

# %%
model = LinearRegression()
model.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
predictions = model.predict(X_test)
predictions
# Out:
# array([1233672.78601458, 1417035.38957336, 1074655.8061009 ,
#        1380398.48736932,  903073.38124346, 1149125.86342014,
#        1208370.41054363, 1412060.09296967, 1520259.86144965,
#        1739221.49182926, 1307295.36132125, 1354667.66759936,
#        1584088.56182232,  784593.5961472 , 1413378.6935031 ,
#        1094334.99380759, 1236315.58984881, 1066934.04580822,
#         603440.07424376,  662951.17374234])

# %%
error = np.sqrt(metrics.mean_absolute_error(Y_test, predictions))

# %%
error
# Out:
# 241.62798288304353
